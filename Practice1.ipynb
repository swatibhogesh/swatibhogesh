# %% [markdown]
# <a href="https://colab.research.google.com/github/swatibhogesh/swatibhogesh/blob/main/Practice1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import datetime

# %% [markdown]
# DataFrame

# %%
students = ['Alice','Bob','Emily','Charlie']

# %%
scores = [90,80,65,50]

# %%
exam_results = pd.DataFrame(
{
    "Name" : students,
    "Scores" : scores
}
)

# %%
exam_results
# Out:
#       Name  Scores
# 0    Alice      90
# 1      Bob      80
# 2    Emily      65
# 3  Charlie      50

# %%
exam_results.loc[0,'Scores']
# Out:
# 90

# %%
exam_results.loc[:,'Scores']
# Out:
# 0    90
# 1    80
# 2    65
# 3    50
# Name: Scores, dtype: int64

# %%
exam_results.loc[2,:]
# Out:
# Name      Emily
# Scores       65
# Name: 2, dtype: object

# %%
exam_results["Scores"]
# Out:
# 0    90
# 1    80
# 2    65
# 3    50
# Name: Scores, dtype: int64

# %% [markdown]
# Add Colums to existing Dataframe

# %%
gender = ['Female','Male','Female','Male']

# %%
exam_results['gender'] = gender

# %%
exam_results
# Out:
#       Name  Scores  gender
# 0    Alice      90  Female
# 1      Bob      80    Male
# 2    Emily      65  Female
# 3  Charlie      50    Male

# %%
exam_results['gender']
# Out:
# 0    Female
# 1      Male
# 2    Female
# 3      Male
# Name: gender, dtype: object

# %% [markdown]
# To remove column from Data Frame

# %%
exam_results.drop('Name',axis=1)
# Out:
#    Scores  gender
# 0      90  Female
# 1      80    Male
# 2      65  Female
# 3      50    Male

# %%
exam_results
#The name doesnt get deeleted permanently
#exam_results.drop('Name',axis=1,inplace=True) - This delets the column permanently
# Out:
#       Name  Scores  gender
# 0    Alice      90  Female
# 1      Bob      80    Male
# 2    Emily      65  Female
# 3  Charlie      50    Male

# %% [markdown]
# Column names and Row Indexes

# %%
exam_results.columns
# Out:
# Index(['Name', 'Scores', 'gender'], dtype='object')

# %%
exam_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Scores  4 non-null      int64
#  2   gender  4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 224.0+ bytes

# %%
exam_results.describe()
#It gives Statistics of the dataframe
# Out:
#        Scores
# count    4.00
# mean    71.25
# std     17.50
# min     50.00
# 25%     61.25
# 50%     72.50
# 75%     82.50
# max     90.00

# %% [markdown]
# To rename Column Names

# %%
exam_results.rename({'Name':'FirstName'},axis=1)
# Out:
#   FirstName  Scores  gender
# 0     Alice      90  Female
# 1       Bob      80    Male
# 2     Emily      65  Female
# 3   Charlie      50    Male

# %% [markdown]
# To deal with missing values

# %%
sparse = pd.DataFrame(
    {'a':[1,2,3],
    'b':[np.nan,4,np.nan],
    'c':[5,np.nan,np.nan]}
)

# %%
sparse
# Out:
#    a    b    c
# 0  1  NaN  5.0
# 1  2  4.0  NaN
# 2  3  NaN  NaN

# %%
sparse.isna()
#To check which values are null.It shows True to which values are null
# Out:
#        a      b      c
# 0  False   True  False
# 1  False  False   True
# 2  False   True   True

# %%
sparse.fillna(0)
#To fill null datas as 0(To fill null values with what we want)
# Out:
#    a    b    c
# 0  1  0.0  5.0
# 1  2  4.0  0.0
# 2  3  0.0  0.0

# %%
sparse
# Out:
#    a    b    c
# 0  1  NaN  5.0
# 1  2  4.0  NaN
# 2  3  NaN  NaN

# %%
sparse.dropna(axis=1)
#To drop null values
#The column whuch contain null values are dropped
# Out:
#    a
# 0  1
# 1  2
# 2  3

# %% [markdown]
# Group By

# %%
exam_results
# Out:
#       Name  Scores  gender
# 0    Alice      90  Female
# 1      Bob      80    Male
# 2    Emily      65  Female
# 3  Charlie      50    Male

# %%
exam_results.groupby('gender').mean()
#Grouped them based on gender and mean of scores
# Out:
#         Scores
# gender
# Female    77.5
# Male      65.0

# %%
mylist=[1,2,1,2]

exam_results.groupby(mylist).get_group(1)
# Out:
#     Name  Scores  gender
# 0  Alice      90  Female
# 2  Emily      65  Female

# %%
exam_results.groupby(mylist).get_group(2)
# Out:
#       Name  Scores gender
# 1      Bob      80   Male
# 3  Charlie      50   Male

# %%
exam_results.groupby('gender').get_group('Male')
# Out:
#       Name  Scores gender
# 1      Bob      80   Male
# 3  Charlie      50   Male

# %%
#Group the people who obtained marks aove or below 70

above_70 = exam_results['Scores'] > 70
above_70
#people whose marks were above 70 are returned as True
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# Name: Scores, dtype: bool

# %%
exam_results
# Out:
#       Name  Scores  gender
# 0    Alice      90  Female
# 1      Bob      80    Male
# 2    Emily      65  Female
# 3  Charlie      50    Male

# %%
#Mean for students whose score are above or below 70
exam_results.groupby(above_70).mean()
# Out:
#         Scores
# Scores
# False     57.5
# True      85.0

# %% [markdown]
# Merging and Joining

# %%
contacts = pd.DataFrame(
    {
        'Name':['Alice','Charlie'],
        'Tel' :['+91 999 999 99 99','+91 888 888 88 88']  
       }
)

# %%
contacts
# Out:
#       Name                Tel
# 0    Alice  +91 999 999 99 99
# 1  Charlie  +91 888 888 88 88

# %%
exam_results.merge(contacts, left_on='Name',right_on='Name')
#defaults to inner join
# Out:
#       Name  Scores  gender                Tel
# 0    Alice      90  Female  +91 999 999 99 99
# 1  Charlie      50    Male  +91 888 888 88 88

# %%
exam_results.merge(contacts,left_on='Name',right_on='Name',how='outer')
# Out:
#       Name  Scores  gender                Tel
# 0    Alice      90  Female  +91 999 999 99 99
# 1      Bob      80    Male                NaN
# 2    Emily      65  Female                NaN
# 3  Charlie      50    Male  +91 888 888 88 88
